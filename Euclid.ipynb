# %%
def gcd(Num1, Num2):
    #Находим остаток
    leftover = Num1 % Num2
    #Если остаток нулевой, то НОД это последний ненулевой остаток
    if leftover == 0:
        return Num2
    else:
        return gcd(Num2, leftover)
gcd(56, 98)
# Out:
# 14
