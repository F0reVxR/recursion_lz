# %%
def is_perfect_number(Num, i = 1):
    
    if i == Num:
        return 0
    if Num % i == 0:
        return i + is_perfect_number(Num, i + 1)
    else:
        return is_perfect_number(Num, i + 1)
    return is_perfect_number(Num) == Num
is_perfect_number(28)
# Out:
# 28
